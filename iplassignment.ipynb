# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\Darshil Shetty\Downloads\IPL_Dataset.csv")

# %%
print(data)
print(data['Runs'].dtype)
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# ...

# %%
#q1
M=data.nlargest(10,'Mat')
M=M.sort_values(by=['Mat'],ascending=False)


k=data.index
data.replace(data.index,p)
M=M.loc[:,'Player':'Mat']
N=M.reset_index()


print(M)
print(N.drop(['index'],axis=1))
# Out:
#               Player  Mat
# 1     Shikhar Dhawan   17
# 3       Shreyas Iyer   17
# 19    Marcus Stoinis   17
# 67     Kagiso Rabada   17
# 2       David Warner   16
# 5    Quinton de Kock   16
# 6   Suryakumar Yadav   16
# 12     Manish Pandey   16
# 31    Kieron Pollard   16
# 54     Krunal Pandya   16
#              Player  Mat
# 0    Shikhar Dhawan   17
# 1      Shreyas Iyer   17
# 2    Marcus Stoinis   17
# 3     Kagiso Rabada   17
# 4      David Warner   16
# 5   Quinton de Kock   16
# 6  Suryakumar Yadav   16
# 7     Manish Pandey   16
# 8    Kieron Pollard   16
# 9     Krunal Pandya   16

# %%
#q2
M=data.nlargest(10,'Avg')
M=M.sort_values(by=['Avg'],ascending=False)
M=M.reset_index()
print(M.drop(['index'],axis=1))
# Out:
#    POS           Player  Mat  Inns  NO  Runs    HS     Avg   BF      SR  100  \
# 0   58     Deepak Hooda    7     5   4   101   62*  101.00   71  142.25    0
# 1   61       Tom Curran    5     4   3    83   54*   83.00   62  133.87    0
# 2   37  Wriddhiman Saha    4     4   1   214    87   71.33  153  139.86    0
# 3    5     Ishan Kishan   14    13   4   516    99   57.33  354  145.76    0
# 4    1         KL Rahul   14    14   2   670  132*   55.83  518  129.34    1
# 5   32   Kieron Pollard   16    12   7   268   60*   53.60  140  191.42    0
# 6   38  Ruturaj Gaikwad    6     6   2   204    72   51.00  169  120.71    0
# 7   34  Ravindra Jadeja   14    11   6   232    50   46.40  135  171.85    0
# 8   10   AB de Villiers   15    14   4   454   73*   45.40  286  158.74    0
# 9   25  Kane Williamson   12    11   4   317    67   45.28  237  133.75    0
#
#    50  4s  6s
# 0   1   5   5
# 1   1   5   3
# 2   2  24   5
# 3   4  36  30
# 4   5  58  23
# 5   1  15  22
# ...

# %%
#q3
k=data.groupby('Player')['Mat'].mean()
print(k)
# Out:
# Player
# AB de Villiers       15.0
# Aaron Finch          12.0
# Abdul Samad          12.0
# Abhishek Sharma       8.0
# Ajinkya Rahane        9.0
#                      ...
# Virat Kohli          15.0
# Washington Sundar    15.0
# Wriddhiman Saha       4.0
# Yashasvi Jaiswal      3.0
# Yuzvendra Chahal     15.0
# Name: Mat, Length: 133, dtype: float64

# %%
data['Mat'].dtype
# Out:
# dtype('int64')

# %%
print(data.index)
# Out:
# Index(['KL Rahul', 'Shikhar Dhawan', 'David Warner', 'Shreyas Iyer',
#        'Ishan Kishan', 'Quinton de Kock', 'Suryakumar Yadav',
#        'Devdutt Padikkal', 'Virat Kohli', 'AB de Villiers',
#        ...
#        'Yuzvendra Chahal', 'Mitchell Marsh', 'Umesh Yadav',
#        'Bhuvneshwar Kumar', 'Sheldon Cottrell', 'Khaleel Ahmed',
#        'Arshdeep Singh', 'Daniel Sams', 'Shreevats Goswami', 'Trent Boult'],
#       dtype='object', name='Player', length=133)

# %%
#q4
print(data)
d=pd.to_numeric(data['HS'],errors='ignore')

g=data.corr()
print(g)
h=g.style.set_table_styles([{'selector':'th','props':[('font-size','25px')]}])

plt.imshow(g)
cbar=plt.colorbar()
plt.show()
plt.imshow(data)
print(h)
# Out:
#                    POS  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# Player
# KL Rahul             1   14    14   2   670   NaN  55.83  518  129.34    1
# Shikhar Dhawan       2   17    17   3   618   NaN  44.14  427  144.73    2
# David Warner         3   16    16   2   548   NaN  39.14  407  134.64    0
# Shreyas Iyer         4   17    17   2   519   NaN  34.60  421  123.27    0
# Ishan Kishan         5   14    13   4   516  99.0  57.33  354  145.76    0
# ...                ...  ...   ...  ..   ...   ...    ...  ...     ...  ...
# Khaleel Ahmed      129    7     1   0     0   NaN   0.00    2    0.00    0
# Arshdeep Singh     130    8     1   0     0   NaN   0.00    3    0.00    0
# Daniel Sams        131    3     1   0     0   NaN   0.00    2    0.00    0
# Shreevats Goswami  132    2     2   0     0   NaN   0.00    4    0.00    0
# Trent Boult        133   15     1   0     0   NaN   0.00    1    0.00    0
#
#                    50  4s  6s
# Player
# ...

# %%
#q5
data[(data['Avg']>50) & (data['SR']>120 )]
# Out:
#     POS           Player  Mat  Inns  NO  Runs    HS     Avg   BF      SR  100  \
# 0     1         KL Rahul   14    14   2   670  132*   55.83  518  129.34    1
# 4     5     Ishan Kishan   14    13   4   516    99   57.33  354  145.76    0
# 31   32   Kieron Pollard   16    12   7   268   60*   53.60  140  191.42    0
# 36   37  Wriddhiman Saha    4     4   1   214    87   71.33  153  139.86    0
# 37   38  Ruturaj Gaikwad    6     6   2   204    72   51.00  169  120.71    0
# 57   58     Deepak Hooda    7     5   4   101   62*  101.00   71  142.25    0
# 60   61       Tom Curran    5     4   3    83   54*   83.00   62  133.87    0
#
#     50  4s  6s
# 0    5  58  23
# 4    4  36  30
# 31   1  15  22
# 36   2  24   5
# 37   3  16   6
# 57   1   5   5
# 60   1   5   3

# %%
#q6
data[(data['Avg']>40) & (data['BF']>100 )]
# Out:
#     POS           Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1         KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2   Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 4     5     Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 8     9      Virat Kohli   15    15   4   466   90*  42.36  384  121.35    0
# 9    10   AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11   Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# 14   15      Eoin Morgan   14    14   4   418   68*  41.80  302  138.41    0
# 24   25  Kane Williamson   12    11   4   317    67  45.28  237  133.75    0
# 27   28      Chris Gayle    7     7   0   288    99  41.14  210  137.14    0
# 28   29       Ben Stokes    8     8   1   285  107*  40.71  200  142.50    1
# 31   32   Kieron Pollard   16    12   7   268   60*  53.60  140  191.42    0
# ...

# %%
#q7
data[(data['Avg']>45) & (data['SR']>135 )&(data['Runs']>300)]
# Out:
#    POS          Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  50  \
# 4    5    Ishan Kishan   14    13   4   516   99  57.33  354  145.76    0   4
# 9   10  AB de Villiers   15    14   4   454  73*  45.40  286  158.74    0   5
#
#    4s  6s
# 4  36  30
# 9  33  23

# %%
#q8
data[(data['100']>=1) ]
# Out:
#     POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 13   14  Mayank Agarwal   11    11   0   424   106  38.54  271  156.45    1
# 28   29      Ben Stokes    8     8   1   285  107*  40.71  200  142.50    1
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 13   2  44  15
# 28   1  36   7

# %%
#q9
data[(data['50']>=4) ]
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2     3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6     7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
# 7     8  Devdutt Padikkal   15    15   0   473    74  31.53  379  124.80    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11    Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 2    4  52  14
# 4    4  36  30
# 5    4  46  22
# 6    4  61  11
# 7    5  51   8
# 9    5  33  23
# 10   4  42  14

# %%
#q10
data[(data['6s']>10) & (data['4s']|data['6s']>45 )]
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2     3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3     4      Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6     7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11    Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# 12   13     Manish Pandey   16    15   2   425   83*  32.69  333  127.62    0
# 13   14    Mayank Agarwal   11    11   0   424   106  38.54  271  156.45    1
# ...

# %%
#q13
r=data.nlargest(20,'Runs')
print(r)
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2     3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3     4      Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6     7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
# 7     8  Devdutt Padikkal   15    15   0   473    74  31.53  379  124.80    0
# 8     9       Virat Kohli   15    15   4   466   90*  42.36  384  121.35    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11    Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# ...

# %%
#q15
r=data.nlargest(30,'Runs')
print(r)
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2     3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3     4      Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6     7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
# 7     8  Devdutt Padikkal   15    15   0   473    74  31.53  379  124.80    0
# 8     9       Virat Kohli   15    15   4   466   90*  42.36  384  121.35    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11    Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# ...

# %%
#q11
data['Mat'].plot(kind='hist',bins=10,edgecolor='black')
plt.ylabel=('frequency')
plt.xlabel=('Matches')

# %%
data['BF'].plot(kind='hist',bins=10,edgecolor='black',color='green')
plt.ylabel=('frequency')
plt.xlabel=('balls fced')

# %%
#q14
df=data.sort_values(by='SR',ascending=False)

print(df)
print(data)
df=df.head(20)
plt.bar(df['Player'],df['SR'],align='center')
plt.xticks(rotation=90)
# Out:
#      POS             Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  \
# 31    32     Kieron Pollard   16    12   7   268  60*  53.60  140  191.42
# 50    51       Jofra Archer   14    10   4   113  27*  18.83   63  179.36
# 29    30      Hardik Pandya   14    13   5   281  60*  35.12  157  178.98
# 83    84   Tushar Deshpande    5     2   1    21  20*  21.00   12  175.00
# 33    34    Ravindra Jadeja   14    11   6   232   50  46.40  135  171.85
# ..   ...                ...  ...   ...  ..   ...  ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0   0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0   0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0   0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0   0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0   0*   0.00    1    0.00
#
#      100  50  4s  6s
# 31     0   1  15  22
# 50     0   0   5  10
# ...

# %%
#q16
plt.scatter(data['Runs'],data['BF'])

# %%
#q17
import seaborn as sns
sns.kdeplot(data['Mat'],color='b',shade=True,label='m',legend='k')
sns.kdeplot(data['Avg'],color='g',shade=True,label='n',legend='j')
# Out:
# C:\Users\Darshil Shetty\AppData\Local\Temp\ipykernel_9436\1137027016.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Mat'],color='b',shade=True,label='m',legend='k')
# C:\Users\Darshil Shetty\AppData\Local\Temp\ipykernel_9436\1137027016.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Avg'],color='g',shade=True,label='n',legend='j')
# <Axes: xlabel='Mat', ylabel='Density'>
